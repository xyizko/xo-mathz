# %% [markdown]
# <div style="text-align: center">
# <img src="https://raw.githubusercontent.com/xyizko/xo-mathz/refs/heads/main/gfx/x.jpeg">
# <img src="https://raw.githubusercontent.com/xyizko/xo-tagz/refs/heads/main/gfx/i.png">
# </div>
# <div style="background: black; color: #00ff00; padding: 2px; text-align: center;background-size: cover; padding: 10px; text-shadow: 00 0 20px #ec4899">
#     <h1> Continuation of yt-fca-1</h1>
#
# </div>

# %%
# Python Beautify
# Python Beautifiers 
import logging
from rich import print as rprint  # For rprinting
from rich.pretty import pprint  # For pretty printing
from rich import inspect  # For inspect
from rich.console import Console  # For console.print
from rich.markdown import Markdown  # For markdow
from rich.panel import Panel  # For Panel()
from rich import box  # For Panel Boxes
from rich.prompt import Prompt  # For Prompting
from rich.style import Style  # For styles colors
from rich.text import Text  # For text Styles
from rich.logging import RichHandler
from rich.traceback import install
from rich.rule import Rule # Horizontal Line
import random

console = Console()  # Standard code to access console
install(show_locals=True)

# Setting up rich logger with color
logging.basicConfig(
    level=logging.DEBUG,
    format="%(message)s",
    datefmt="[%X]",
    handlers=[RichHandler(rich_tracebacks=True, markup=True)],
)
log = logging.getLogger("rich")

# Horizontal Line 
def dividerz(title: str = "", color: str = ""):
    console.print(Rule(f"{title}", style=f"{color}"))

# boxa
def boxa(txt: str = "", title: str = "", subtitle: str = "", brd: str = ""):
    console.print(Panel.fit(f"{txt}",
                            title=f"{title}",
                            subtitle=f"{subtitle}", 
                            style="Italic", 
                            border_style=f"{brd}"))
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# > This note boook is a continuation of [`yt-fca-1`](https://www.kaggle.com/code/xyizko/yt-fca-1/)

# %% [markdown]
# # TOC
# 1. [Important Libraries](#libraries)
# 2. [PLotting Functions](#plotting-functions)

# %% [markdown]
# # Libraries
#
# 1. Information regarding libraries used

# %% [markdown]
# [🔙](#TOC)
#
# # Plotting Functions

# %%
#--------------------------------------------------------------
# Working Example
#--------------------------------------------------------------
# Complete Example 
import matplotlib.pyplot as plt
import numpy as np

# Apply the built-in dark_background style
plt.style.use('dark_background')

# Generate some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, y, label='sin(x)')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Plot with dark_background style')

# Add a legend and grid
ax.legend()
ax.grid(True)

# Display the plot
plt.show()

# %%
# Example with all available color and shepes

import matplotlib.pyplot as plt

def plt1():
    # Define axis limits
    xmin = -10
    xmax = 10
    ymin = -10
    ymax = 10

    # Use dark background style
    plt.style.use('dark_background')
    fig, ax = plt.subplots(figsize=(12, 8))

    # Labels and title
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('Matplotlib: Marker Shapes and Colors', fontsize=14, color='white')

    # Set plot dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw axis lines (centered at 0)
    plt.plot([xmin, xmax], [0, 0], color='gray', linewidth=1)
    plt.plot([0, 0], [ymin, ymax], color='gray', linewidth=1)

    # --- MARKER TYPES (displayed vertically for each type) ---
    markers = [
        ('.', 'point'),
        ('o', 'circle'),
        ('^', 'triangle up'),
        ('v', 'triangle down'),
        ('<', 'triangle left'),
        ('>', 'triangle right'),
        ('s', 'square'),
        ('p', 'pentagon'),
        ('*', 'star'),
        ('+', 'plus'),
        ('x', 'x'),
        ('D', 'diamond'),
        ('h', 'hexagon'),
        ('1', 'tri_down'),
        ('2', 'tri_up'),
        ('3', 'tri_left'),
        ('4', 'tri_right'),
    ]

    # Basic colors with names
    colors = ['r', 'g', 'b', 'c', 'm', 'y', 'w']
    color_names = ['Red', 'Green', 'Blue', 'Cyan', 'Magenta', 'Yellow', 'White']

    # Place markers on grid
    x_start = -8
    y_start = 6
    x_step = 2
    y_step = 1.5

    for i, (marker, label) in enumerate(markers):
        y = y_start - i * y_step
        # Show marker label
        ax.text(x_start - 1.5, y, label, fontsize=9, color='lightgray', verticalalignment='center')

        # Plot this marker in all colors
        for j, color in enumerate(colors):
            x = x_start + j * x_step
            plt.plot(x, y, marker=marker, color=color, markersize=8)

    # Add color legend at the top
    for j, (color, name) in enumerate(zip(colors, color_names)):
        ax.text(x_start + j * x_step, y_start + 1, name, fontsize=10, color=color,
                horizontalalignment='center', weight='bold')

    # Final touch
    ax.grid(True, alpha=0.2)
    plt.show()

# --- Execution ---
plt1()

# %%
# Adding custom axis 

# --- Imports --- 

import matplotlib.pyplot as plt

# --- Funtiions ---

def plt1():

    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10
    
    
    # Dark style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt1()')
    ax.grid(True, alpha=0.2)

    # plots dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw Axis Lines
    plt.plot([xmin,xmax],[0,0])
    plt.plot([0,0],[ymin,ymax])
    
    

    # Show plot function
    plt.show()    

# --- Execution ---
plt1()

# %%
# Plotting points
# --- Imports --- 

import matplotlib.pyplot as plt

# --- Funtiions ---

def plt1():

    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10
    
    
    # Dark style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt1()')
    ax.grid(True, alpha=0.2)

    # plots dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw Axis Lines
    plt.plot([xmin,xmax],[0,0])
    plt.plot([0,0],[ymin,ymax])

    # Plotting points
    plt.plot([5],[4], 'ro') # ro = red circle
    plt.plot([2],[4], 'm.') # m. = Magenta Dot
    plt.plot([-3],[4], 'bo') # bo = Bleu Circle
    plt.plot([-3],[2], 'g^') # m. = Green Triangle
        

    # Show plot function
    plt.show()    

# --- Execution ---
plt1()

# %% [markdown]
# *Note you will issues if you keep using the same function name. As you move from cell to cell , the function names are still active, until the notebook session is reset*

# %%
# --- Imports ---
import matplotlib.pyplot as plt

# --- Functions ---
def plt2():
    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10
    
    # Dark style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt2()')  # Fixed function name in title
    ax.grid(True, alpha=0.2)

    # Plot dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw Axis Lines
    plt.plot([xmin, xmax], [0, 0], linewidth=0.5, color="white")  # X-axis
    plt.plot([0, 0], [ymin, ymax], linewidth=0.5, color="white")  # Y-axis

    # Plotting points using loop
    for x in range(10):
        y = 0.5 * x + 1
        plt.plot([x], [y], "y.", markersize=5)  

    # Show plot
    plt.show()

# --- Execution ---
plt2()  # Also fixed: calling plt2(), not plt1()

# %%
# plt3 =  Plotting the table and the plot

# --- Imports ---
import matplotlib.pyplot as plt

# --- Functions ---
def plt3():
    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10
    
    # Dark style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt2()')  # Fixed function name in title
    ax.grid(True, alpha=0.2)

    # Plot dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw Axis Lines
    plt.plot([xmin, xmax], [0, 0], linewidth=0.5, color="white")  # X-axis
    plt.plot([0, 0], [ymin, ymax], linewidth=0.5, color="white")  # Y-axis

    # Expplanation box 
    boxa("Plotting with Plot and Value Table")

    # Plotting points using loop
    for x in range(xmin,xmax+1): # Range can be defined here
        y = 0.5 * x + 1
        rprint(f"Values - {x}\t{y}")
        plt.plot([x], [y], "y.", markersize=5)  

    # Show plot
    plt.show()

# --- Execution ---
plt3()  # Also fixed: calling plt2(), not plt1()
# Out:
# ╭────────────────────────────────────╮
# │ Plotting with Plot and Value Table │
# ╰────────────────────────────────────╯
# Values - -10    -4.0
# Values - -9     -3.5
# Values - -8     -3.0
# Values - -7     -2.5
# Values - -6     -2.0
# Values - -5     -1.5
# Values - -4     -1.0
# Values - -3     -0.5
# Values - -2     0.0
# Values - -1     0.5
# Values - 0      1.0
# Values - 1      1.5
# Values - 2      2.0
# Values - 3      2.5
# Values - 4      3.0
# Values - 5      3.5
# Values - 6      4.0
# Values - 7      4.5
# Values - 8      5.0
# Values - 9      5.5
# Values - 10     6.0

# %%
# plt4 - Plotting  with table using rich 

# --- Imports ---
import matplotlib.pyplot as plt
from rich.console import Console
from rich.table import Table

# --- Functions ---
def plt4():
    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10
    
    # Dark style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt2()')
    ax.grid(True, alpha=0.2)

    # Plot dimensions
    plt.axis([xmin, xmax, ymin, ymax])

    # Draw Axis Lines
    plt.plot([xmin, xmax], [0, 0], linewidth=0.5, color="white")  # X-axis
    plt.plot([0, 0], [ymin, ymax], linewidth=0.5, color="white")  # Y-axis

    # Explanation box (assuming boxa is defined elsewhere)
    boxa("Plotting with Plot and Value Table")

    # Create a Rich table
    console = Console()
    table = Table(title="Value Table: y = 0.5x + 1")
    table.add_column("X", justify="center", style="cyan", no_wrap=True)
    table.add_column("Y", justify="center", style="magenta", no_wrap=True)

    # Plotting points using loop and adding values to table
    for x in range(xmin, xmax + 1):
        y = 0.5 * x + 1
        table.add_row(str(x), f"{y:.2f}")  # Format y to 2 decimal places
        plt.plot([x], [y], "y.", markersize=5)  

    # Print the table
    console.print(table)

    # Show plot
    plt.show()

# --- Execution ---
plt4()
# Out:
# ╭────────────────────────────────────╮
# │ Plotting with Plot and Value Table │
# ╰────────────────────────────────────╯
# Value Table: y
#   = 0.5x + 1
# ┏━━━━━┳━━━━━━━┓
# ┃  X  ┃   Y   ┃
# ┡━━━━━╇━━━━━━━┩
# │ -10 │ -4.00 │
# │ -9  │ -3.50 │
# │ -8  │ -3.00 │
# │ -7  │ -2.50 │
# │ -6  │ -2.00 │
# │ -5  │ -1.50 │
# │ -4  │ -1.00 │
# │ -3  │ -0.50 │
# │ -2  │ 0.00  │
# │ -1  │ 0.50  │
# │  0  │ 1.00  │
# │  1  │ 1.50  │
# │  2  │ 2.00  │
# │  3  │ 2.50  │
# │  4  │ 3.00  │
# │  5  │ 3.50  │
# │  6  │ 4.00  │
# │  7  │ 4.50  │
# │  8  │ 5.00  │
# │  9  │ 5.50  │
# │ 10  │ 6.00  │
# └─────┴───────┘

# %% [markdown]
# ## Extra problems
# 1. Doing extra math problems here

# %%
# plt5 Using arrays to plot

# --- Imports ---

import matplotlib.pyplot as plt
import numpy as np 

# --- Functions ---

def plt5():

    # Defining axis
    xmin = -10
    xmax = +10
    ymin = -10
    ymax = +10

    points = 2*(xmax - xmin)
    x = np.linspace(xmin, xmax, points) #linspace sets up an arry with 
    rprint(f"Values in x = {x}")

    # Plot style
    plt.style.use('dark_background')
    fig, ax = plt.subplots()

    # Draw Axis Lines
    plt.plot([xmin, xmax], [0, 0], linewidth=0.5, color="white")  # X-axis
    plt.plot([0, 0], [ymin, ymax], linewidth=0.5, color="white")  # Y-axis

    # Plot style and labels
    plt.axis([xmin, xmax, ymin, ymax])
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_title('pt5() - Plotting array of numbers ')
    ax.grid(True, alpha=0.15)

    # Equation
    y = 2*x + 1
    plt.plot(x,y, 'y')

    # Show plot
    plt.show()



# --- Execution --- 

plt5()
# Out:
# Values in x = [-10.          -9.48717949  -8.97435897  -8.46153846  -7.94871795
#   -7.43589744  -6.92307692  -6.41025641  -5.8974359   -5.38461538
#   -4.87179487  -4.35897436  -3.84615385  -3.33333333  -2.82051282
#   -2.30769231  -1.79487179  -1.28205128  -0.76923077  -0.25641026
#    0.25641026   0.76923077   1.28205128   1.79487179   2.30769231
#    2.82051282   3.33333333   3.84615385   4.35897436   4.87179487
#    5.38461538   5.8974359    6.41025641   6.92307692   7.43589744
#    7.94871795   8.46153846   8.97435897   9.48717949  10.        ]

# %% [markdown]
# Notes
# 1. In the above function - in the line - ` plt.plot(x,y, 'y')` , the line is defined here, along with `y` if you add a marker it will be interpreted as requiring point,
#     -  eg: `r^` = plots red triangles
#     -  eg: `g` =  plots green line

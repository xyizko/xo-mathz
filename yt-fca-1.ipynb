# %% [markdown]
# <div style="background: url(https://media1.giphy.com/media/l4FGrWakDMBD8f8Lm/200.webp) repeat; color: #00ff00; padding: 2px; text-align: center;background-size: cover; text-shadow: 00 0 20px #ec4899">
#     <h1>YouTube Precalculus - Full Course with Python Code</h1>
#
# </div>

# %% [markdown]
# # Youtube - Full College Algebra In Python
#
# 1. This workbook is for all the exercises.
# 2. The goal is to run pure mathematical operations in python.
# 3. This notebook has been originally being worked from Kaggle. But it is compatible with JupyterNotebooks.
